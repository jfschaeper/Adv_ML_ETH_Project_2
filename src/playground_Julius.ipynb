# %% [markdown]
# # Playground

# %%
import biosppy.signals.ecg as ecg
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rcParams["figure.figsize"] = (30, 20)

# %%
df = pd.read_csv('../data/X_train.csv', index_col='id')

# %%
signal = df.loc[0].dropna().to_numpy(dtype='float32')

r_peaks = ecg.engzee_segmenter(signal, 300)['rpeaks']
beats = ecg.extract_heartbeats(signal, r_peaks, 300)['templates']
ecg_more = ecg.ecg(signal, 300)

# %%
len(ecg_more['filtered'])
# Out:
# 16279

# %%
plt.plot(range(beats[0].shape[0]), beats[0])

# %%
b = 3
plt.plot(range(beats[b].shape[0]), beats[b])

# %%
plt.plot(range(signal[500:1500].shape[0]), signal[500:1500])

# %%
from functions import *
import numpy as np
import pandas as pd

# load data 
X_train = pd.read_csv('../data/X_train.csv', index_col='id')
X_test = pd.read_csv('../data/X_test.csv', index_col='id')
X = pd.concat([X_train, X_test])

# %%
X.iloc[len(X_train) :len(X)]
# Out:
#         x0    x1    x2    x3    x4    x5    x6   x7   x8   x9  ...  x17832  \
# id                                                             ...
# 0       30    29    28    27    26    24    24   28   38   49  ...     NaN
# 1      -75   -72   -70   -67   -64   -61   -59  -56  -53  -51  ...     NaN
# 2      264   280   289   293   298   302   306  308  309  310  ...     NaN
# 3     -377  -380  -383  -385  -388  -391  -394 -397 -400 -402  ...     NaN
# 4      -69   -67   -66   -65   -65   -66   -68  -70  -73  -76  ...     NaN
# ...    ...   ...   ...   ...   ...   ...   ...  ...  ...  ...  ...     ...
# 3406   -21   -68   -93  -113  -127  -134  -138 -141 -143 -144  ...     NaN
# 3407  -122  -116  -112  -111  -110  -109  -108 -108 -107 -107  ...     NaN
# 3408    -9    -7    -5    -3    -1     0     2    7   11   13  ...     NaN
# 3409    31    28    26    23    22    20    18   16   14   11  ...     NaN
# 3410  1659  1577  1484  1375  1260  1150  1051  965  895  862  ...     NaN
#
# ...

# %%
X_train
# Out:
#        x0   x1   x2   x3   x4   x5   x6   x7   x8   x9  ...  x17832  x17833  \
# id                                                      ...
# 0     -64  -66  -69  -72  -75  -77  -80  -86  -89  -83  ...     NaN     NaN
# 1     505  500  496  492  487  480  475  476  483  495  ...     NaN     NaN
# 2     -21  -16  -12   -7   -3    0    1    2    4    5  ...     NaN     NaN
# 3    -211 -457 -635 -710 -715 -663 -573 -481 -401 -337  ...     NaN     NaN
# 4      36   32   29   25   22   19   17   15   12   10  ...     NaN     NaN
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...     ...
# 5112 -285 -303 -334 -376 -413 -432 -443 -451 -460 -468  ...     NaN     NaN
# 5113   50   51   50   48   46   44   42   39   36   33  ...     NaN     NaN
# 5114 -207 -225 -242 -258 -266 -271 -275 -279 -281 -284  ...     NaN     NaN
# 5115   13   16   18   21   23   24   25   27   29   32  ...     NaN     NaN
# ...
